# %% [markdown]
# # **SALES PREDICTION USING PYTHON**

# %%
import pandas as pd

# %% [markdown]
# ## Getting Dataset

# %%
path = '/content/drive/MyDrive/Datasets/Advertising.csv'
df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Checking, cleaning data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Dividing data into variables

# %%
x = df.drop(columns=['Sales', 'Unnamed: 0'])
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# ## splitting data into training and testing variables and training the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the outcome

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([ 7.06288204, 14.04293552, 18.4803692 , 12.94502588, 12.15357084,
#         8.48767119, 11.66023678, 21.30157354, 15.49841052,  7.92897838,
#        20.48597038,  8.38523757, 17.2532888 ,  9.82712855, 21.18990867,
#        10.59776268, 11.47060346, 16.91270064, 13.4700822 , 19.97294588,
#         4.38603411, 17.82896358, 15.32787482, 16.70902263, 10.48910178,
#         7.56724378, 13.89524904, 20.93253133, 18.37234478, 16.54051663,
#        17.07166735, 18.28272957,  6.45614178, 17.35492075, 12.64300486,
#        19.17782851, 17.53975111, 14.89455549, 15.32749348,  6.61803984])

# %% [markdown]
# ## Cross Checking the predicted values and actual values

# %%
pd.DataFrame({'Actual': y_test, 'predicted': y_pred})
# Out:
#      Actual  predicted
# 107     8.7   7.062882
# 43     12.9  14.042936
# 150    16.1  18.480369
# 197    12.8  12.945026
# 67     13.4  12.153571
# 191     9.9   8.487671
# 86     12.0  11.660237
# 69     22.3  21.301574
# 146    13.2  15.498411
# 65      9.3   7.928978
# 0      22.1  20.485970
# 56      5.5   8.385238
# 35     12.8  17.253289
# 149    10.1   9.827129
# 93     22.2  21.189909
# 71     12.4  10.597763
# 88     12.9  11.470603
# 62     15.7  16.912701
# 167    12.2  13.470082
# 139    20.7  19.972946
# 76      6.9   4.386034
# 102    14.8  17.828964
# 114    14.6  15.327875
# 194    17.3  16.709023
# 130     1.6  10.489102
# 32      9.6   7.567244
# 174    11.5  13.895249
# 84     21.7  20.932531
# 59     18.4  18.372345
# 152    16.6  16.540517
# 64     18.0  17.071667
# 141    19.2  18.282730
# 182     8.7   6.456142
# 41     17.1  17.354921
# 50     11.4  12.643005
# 33     17.4  19.177829
# 11     17.4  17.539751
# 103    14.7  14.894555
# 156    15.3  15.327493
# ...

# %% [markdown]
# ## Plotting in charts

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.figure(figsize=(10, 5))
sb.regplot(x = y_test, y = y_pred, scatter_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='Sales'>

# %% [markdown]
# ## Getting the distance between Predicted values and Actual values

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 4.610918712938858
